# %%
a=4.5
b=123
s=("hi")
print(f"hi{b}bye")
# Out:
# hi123bye

# %%
print(f"{a}{b}hi")
# Out:
# 4.5123hi

# %%
print(f"{a}bye{b}")
# Out:
# 4.5bye123

# %%
print(f"{10+5}bye{9/2}hi")
# Out:
# 15bye4.5hi

# %%
print(f"{10}{20}{30}{40}")
# Out:
# 10203040

# %%
a=153
b=4.123
print(f"{a}bye{b}")
# Out:
# 153bye4.123

# %%
print(F"{a:04d}bye{b:.2f}")
# Out:
# 0153bye4.12

# %%
a=327
b=19.7567
print(F"{a:0d}bye{b:.1f}")
# Out:
# 327bye19.8

# %%
print(f"{a:02d}byehibye{a+2}{b}{b:.4f}")
# Out:
# 327byehibye32919.756719.7567

# %%
print(10)
print(20)
print(30)
print(40,end="@")
print(15,end="")
print(16,end="")
print(10)
print(25)
# Out:
# 10
# 20
# 30
# 40@151610
# 25

# %%
print("hi",end="")
print(20+30)
print(30/2)
print("bye",end="@")
print("hi1",end="")
print(20,end="")
print(50)
print(20)
# Out:
# hi50
# 15.0
# bye@hi12050
# 20

# %%
for i in range(1,3):
    for j in range(1,4):
        print(i,j,end="@")
    print()
# Out:
# 1 1@1 2@1 3@
# 2 1@2 2@2 3@

# %%
a=2
while(a<=4):
    b=1
    while(b<=2):
        print(a+b)
        b=b+1
    a=a+1
# Out:
# 3
# 4
# 4
# 5
# 5
# 6
