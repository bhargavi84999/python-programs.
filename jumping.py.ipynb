# %%
for i in range(5,10):
    print(i)
    if(i==7):
        break
# Out:
# 5
# 6
# 7

# %%
for i in range(2,7):
    if(i==5):
        break
    print(i)
# Out:
# 2
# 3
# 4

# %%
for i in range(10,15):
    print(i)
    break
# Out:
# 10

# %%
for i in range(5):
    break
    print(i)

# %%
for i in range(5,12):
    if(i//2==4):
        break
    print(i)
# Out:
# 5
# 6
# 7

# %%
a=4
while(a<=7):
    a=a+1
    if(a==6):
        break
    print(a)
# Out:
# 5

# %%
for i in range(5,10):
    if(i==7):
        continue
    print(i)
# Out:
# 5
# 6
# 8
# 9

# %%
for i in range(5,10):
    print(i)
    if(i==7):
        continue
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
for i in range(5):
    print(i)
    continue
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
    continue
    print(i)

# %%
a=4
while(a<=8):
    a=a+1
    if(a==7):
        continue
    print(a)
# Out:
# 5
# 6
# 8
# 9

# %%
for i in range(5,13):
    if(i//2==3):
        continue
    if(i//2==6):
        break
    print(i)
# Out:
# 5
# 8
# 9
# 10
# 11

# %%
a=2
while(a>1):
    print(a)
    a=a+1
    if(a==5):
        break
# Out:
# 2
# 3
# 4

# %%
a=0
while(a<=7):
    a=a+1
    if(a%3==0):
      continue
    if(a//2==3):
       break
    print(a*10)
# Out:
# 10
# 20
# 40
# 50
