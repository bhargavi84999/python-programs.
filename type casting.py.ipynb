# %%
from numpy.ma.core import true_divide

b=4.5
k=True
s="hi"
s1="12"
b=int(b)
print(b)
# Out:
# 4

# %%
k=int(k)
print(k)
# Out:
# 1

# %%
l=int(False)
print(l)
# Out:
# 0

# %%
d=int(s1)
print(s1)
# Out:
# 12

# %%
f1=float(k)
print(f1)
# Out:
# 1.0

# %%
f2=float(False)
print(f2)
# Out:
# 0.0

# %%
f4=float(s1)
print(f4)
# Out:
# 12.0

# %%
s2=12.5
f5=float(s2)
print(f5)
# Out:
# 12.5

# %%
b=bool(k)
print(b)
# Out:
# True

# %%
b1=bool("")
print(b1)
# Out:
# False

# %%
b2=bool(1)
print(b2)
# Out:
# True

# %%
b3=bool(00)
print(b3)
# Out:
# False

# %%
b4=bool(s1)
print(b4)
# Out:
# True

# %%
s4=str(k)

# %%
a=14.56
b=153
print("hi%f"%a)
# Out:
# hi14.560000

# %%
print("bye%d"%b)
# Out:
# bye153

# %%
print("%d"%b)
# Out:
# 153

# %%
a=456
b=14.123
print("%.2f"%b)
# Out:
# 14.12

# %%
print("%.3f"%b)
# Out:
# 14.123

# %%
print("%.5f"%b)
# Out:
# 14.12300

# %%
print("%.1f"%b)
# Out:
# 14.1

# %%
print("%.0f"%b)
# Out:
# 14

# %%
print("hi%.4f"%b)
# Out:
# hi14.1230

# %%
print("%04d"%a)
# Out:
# 0456

# %%
print("%03d"%a)
# Out:
# 456

# %%
print("%05d"%a)
# Out:
# 00456

# %%
print("%02d"%a)
# Out:
# 456

# %%
print("%06d"%a)
# Out:
# 000456

# %%
print("%fhi%d"%(b,a))
# Out:
# 14.123000hi456

# %%
print("%0.4d%.4fbye"%(b,a))
# Out:
# 0014456.0000bye

# %%
print("%.4fbye%0.4dhi"%(b,a))
# Out:
# 14.1230bye0456hi

# %%
s1="hanish"
s2="lohith"
s3=s1+s2
print(s3)
# Out:
# hanishlohith

# %%
a=45
b=123
s4=str(a)+str(b)
print(s4)
# Out:
# 45123

# %%
a=153
b=14.53
s5=str(a)+str(b)
print(s5)
# Out:
# 15314.53
